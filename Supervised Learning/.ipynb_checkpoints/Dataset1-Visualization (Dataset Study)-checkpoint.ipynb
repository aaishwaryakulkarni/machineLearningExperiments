# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
churn_model_df = pd.read_csv("Churn_Modelling.csv")
churn_model_df.drop(["RowNumber", "CustomerId", "Surname"], axis = 1, inplace = True)
churn_model_df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
churn_model_df.describe().T
# Out:
#                    count           mean           std     min       25%  \
# CreditScore      10000.0     650.528800     96.653299  350.00    584.00
# Age              10000.0      38.921800     10.487806   18.00     32.00
# Tenure           10000.0       5.012800      2.892174    0.00      3.00
# Balance          10000.0   76485.889288  62397.405202    0.00      0.00
# NumOfProducts    10000.0       1.530200      0.581654    1.00      1.00
# HasCrCard        10000.0       0.705500      0.455840    0.00      0.00
# IsActiveMember   10000.0       0.515100      0.499797    0.00      0.00
# EstimatedSalary  10000.0  100090.239881  57510.492818   11.58  51002.11
# Exited           10000.0       0.203700      0.402769    0.00      0.00
#
#                         50%          75%        max
# CreditScore         652.000     718.0000     850.00
# Age                  37.000      44.0000      92.00
# Tenure                5.000       7.0000      10.00
# ...

# %%
train_df, test_df = train_test_split(churn_model_df,
                                     test_size = 0.2,
                                     random_state = 42)

train_df.reset_index(drop = True,
                     inplace = True)
test_df.reset_index(drop = True,
                    inplace = True)
print("Training set: {}".format(train_df.shape))
print("Testing set: {}".format(test_df.shape))
# Out:
# Training set: (8000, 11)
# Testing set: (2000, 11)

# %%
x = ['Active','Churned']
y = [len(train_df[train_df['Exited'] == 0]),len(train_df[train_df['Exited'] == 1])]
ax = sns_plot = sns.barplot(x, y)

sns_plot.annotate(len(train_df[train_df['Exited'] == 0]),
                  xy=(0, len(train_df[train_df['Exited'] == 0]) -300),
                  ha='center',
                  va='center',
                  color = 'white',
                  fontweight='bold',
                  size= 12)
sns_plot.annotate(len(train_df[train_df['Exited'] == 1]),
                  xy=(1, len(train_df[train_df['Exited'] == 1]) -300),
                  ha='center',
                  va='center',
                  color = 'white',
                  fontweight='bold',
                  size= 12)
ax.set(ylabel='Training dataset size')
plt.show()
# Out:
# C:\Users\Hp\Anaconda2\envs\ml_assignment1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.rcParams["figure.figsize"] = [12,8]
plt.rcParams["figure.autolayout"] = True

fig, axes = plt.subplots(2, 2)

train_df.hist('Age',
              ax=axes[0][0])
train_df.hist('Balance',
              ax=axes[0][1])
train_df.hist('EstimatedSalary',
              ax=axes[1][0])
train_df.hist('CreditScore',
              ax=axes[1][1])
plt.show()

# %%
fig, axarr = plt.subplots(3, 2, figsize=(12,10))
sns.countplot(x = 'Gender',
              hue = 'Exited',
              data = train_df,
              ax = axarr[0][0])
sns.countplot(x = 'Geography',
              hue = 'Exited',
              data = train_df,
              ax = axarr[0][1])
sns.countplot(x = 'IsActiveMember',
              hue = 'Exited',
              data = train_df,
              ax = axarr[1][0])
sns.countplot(x = 'HasCrCard',
              hue = 'Exited',
              data = train_df,
              ax = axarr[1][1])
sns.countplot(x = 'Tenure',
              hue = 'Exited',
              data = train_df,
              ax = axarr[2][0])
sns.countplot(x = 'NumOfProducts',
              hue = 'Exited',
              data = train_df,
              ax = axarr[2][1])
plt.show()

# %%
fig, axarr = plt.subplots(3, 2, figsize=(12,10))
sns.barplot(x = 'Gender',
              y = 'Exited',
              data = train_df,
              ax = axarr[0][0])
sns.barplot(x = 'Geography',
              y = 'Exited',
              data = train_df,
              ax = axarr[0][1])
sns.barplot(x = 'IsActiveMember',
              y = 'Exited',
              data = train_df,
              ax = axarr[1][0])
sns.barplot(x = 'HasCrCard',
              y = 'Exited',
              data = train_df,
              ax = axarr[1][1])
sns.barplot(x = 'Tenure',
              y = 'Exited',
              data = train_df,
              ax = axarr[2][0])
sns.barplot(x = 'NumOfProducts',
              y = 'Exited',
              data = train_df,
              ax = axarr[2][1])
plt.show()

# %%
fig, axarr = plt.subplots(2, 2, figsize=(8,10))
sns.boxplot(x='Exited',
            y='CreditScore',
            data=train_df,
            ax = axarr[0][0])
sns.boxplot(x='Exited',
            y='Age',
            data=train_df,
            ax = axarr[0][1])
sns.boxplot(x='Exited',
            y='Balance',
            data=train_df,
            ax = axarr[1][0])
sns.boxplot(x='Exited',
            y='EstimatedSalary',
            data=train_df,
            ax = axarr[1][1])
plt.show()
